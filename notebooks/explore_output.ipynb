# %%
import pandas as pd

df = pd.read_parquet('../data/golden/cda/classified.parquet')
df.head()

df.columns
# Out:
# Index(['client', 'sampleNumber', 'sampleDate', 'unitId', 'machineName',
#        'machineModel', 'machineBrand', 'machineHours', 'machineSerialNumber',
#        'componentName', 'componentHours', 'componentSerialNumber', 'oilMeter',
#        'oilBrand', 'oilType', 'oilWeight', 'Hierro', 'Cromo', 'Aluminio',
#        'Cobre', 'Plomo', 'Níquel', 'Plata', 'Estaño', 'Titanio', 'Vanadio',
#        'Manganeso', 'Silicio', 'Potasio', 'Sodio', 'Zinc', 'Bario', 'Boro',
#        'Calcio', 'Molibdeno', 'Magnesio', 'Fósforo', 'componentNameNormalized',
#        'previousSampleNumber', 'previousSampleDate', 'daysSincePrevious',
#        'essays_broken', 'severity_score', 'report_status', 'breached_essays',
#        'unitId_generated', 'componentName_generated', 'sampleDate_generated',
#        'client_generated', 'ai_recommendation', 'ai_generated_at'],
#       dtype='str')
