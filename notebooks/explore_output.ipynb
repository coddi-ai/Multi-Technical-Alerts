# %%
import pandas as pd

df = pd.read_parquet('../data/golden/cda/classified.parquet')
df.head()

df.breached_essays[0]
# Out:
# array([{'essay': 'Aluminio', 'limit': 4.0, 'points': 5, 'threshold': 'Critico', 'value': 5.0},
#        {'essay': 'Potasio', 'limit': 2.0, 'points': 1, 'threshold': 'Marginal', 'value': 2.0},
#        {'essay': 'Sodio', 'limit': 3.0, 'points': 1, 'threshold': 'Marginal', 'value': 3.0}],
#       dtype=object)
